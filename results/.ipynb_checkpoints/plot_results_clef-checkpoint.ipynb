# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import xticks
from matplotlib.pyplot import ylim
# %matplotlib inline

# %%
df = pd.read_csv('results/clef_results.csv', sep=';')
df
# Out:
#    UNCERTAINTYclefw2vecMLPre@10  UNCERTAINTYclefw2vecRFre@10  \
# 0                         0.097                        0.138
# 1                         0.140                        0.163
# 2                         0.145                        0.181
# 3                         0.162                        0.182
# 4                         0.173                        0.195
# 5                         0.175                        0.197
# 6                         0.195                        0.213
# 7                         0.197                        0.254
# 8                         0.200                        0.259
# 9                         0.215                        0.265
#
#    UNCERTAINTYclefw2vecLRre@10  UNCERTAINTYclefw2vecSVMrbfre@10  \
# 0                        0.079                            0.013
# 1                        0.105                            0.064
# 2                        0.120                            0.121
# 3                        0.140                            0.142
# 4                        0.165                            0.167
# 5                        0.176                            0.181
# 6                        0.201                            0.214
# 7                        0.204                            0.225
# 8                        0.205                            0.228
# 9                        0.228                            0.237
#
#    UNCERTAINTYclefgloveMLPre@10  UNCERTAINTYclefgloveRFre@10  \
# 0                         0.036                        0.104
# 1                         0.085                        0.128
# 2                         0.107                        0.144
# 3                         0.109                        0.155
# 4                         0.114                        0.181
# 5                         0.120                        0.196
# 6                         0.124                        0.214
# 7                         0.126                        0.218
# 8                         0.129                        0.223
# 9                         0.132                        0.223
#
#    UNCERTAINTYclefgloveLRre@10  UNCERTAINTYclefgloveSVMrbfre@10  \
# 0                        0.085                            0.006
# 1                        0.128                            0.031
# 2                        0.147                            0.124
# 3                        0.166                            0.142
# 4                        0.168                            0.145
# 5                        0.182                            0.151
# 6                        0.210                            0.174
# 7                        0.218                            0.176
# 8                        0.251                            0.224
# 9                        0.263                            0.228
#
#    UNCERTAINTYclefBERTMLPre@10  UNCERTAINTYclefBERTRFre@10  \
# 0                        0.256                       0.286
# 1                        0.294                       0.348
# 2                        0.328                       0.385
# 3                        0.350                       0.408
# 4                        0.353                       0.444
# 5                        0.372                       0.503
# 6                        0.394                       0.509
# 7                        0.419                       0.513
# 8                        0.419                       0.546
# 9                        0.481                       0.565
#
#              ...             RANDOMclefgloveRFre@10  RANDOMclefgloveLRre@10  \
# 0            ...                              0.074                   0.068
# 1            ...                              0.082                   0.088
# 2            ...                              0.098                   0.092
# 3            ...                              0.102                   0.095
# 4            ...                              0.105                   0.098
# 5            ...                              0.109                   0.107
# 6            ...                              0.112                   0.108
# 7            ...                              0.117                   0.108
# 8            ...                              0.125                   0.108
# 9            ...                              0.128                   0.113
#
#    RANDOMclefgloveSVMrbfre@10  RANDOMclefBERTMLPre@10  RANDOMclefBERTRFre@10  \
# 0                       0.008                   0.032                  0.078
# 1                       0.027                   0.033                  0.083
# 2                       0.058                   0.035                  0.086
# 3                       0.074                   0.040                  0.089
# 4                       0.099                   0.044                  0.097
# 5                       0.118                   0.048                  0.102
# 6                       0.119                   0.049                  0.109
# 7                       0.133                   0.050                  0.114
# 8                       0.133                   0.057                  0.116
# 9                       0.144                   0.082                  0.130
#
#    RANDOMclefBERTLRre@10  RANDOMclefBERTSVMrbfre@10  \
# 0                  0.119                      0.018
# 1                  0.133                      0.030
# 2                  0.138                      0.087
# 3                  0.147                      0.100
# 4                  0.152                      0.117
# 5                  0.154                      0.128
# 6                  0.154                      0.132
# 7                  0.173                      0.138
# 8                  0.175                      0.148
# 9                  0.178                      0.165
#
#    RANDOMclefBioBERTMLPre@10  RANDOMclefBioBERTRFre@10  \
# 0                      0.057                     0.059
# 1                      0.061                     0.060
# 2                      0.061                     0.068
# 3                      0.070                     0.071
# 4                      0.074                     0.074
# 5                      0.076                     0.077
# 6                      0.080                     0.082
# 7                      0.101                     0.108
# 8                      0.120                     0.108
# 9                      0.126                     0.111
#
#    RANDOMclefBioBERTLRre@10
# 0                     0.138
# 1                     0.148
# 2                     0.150
# 3                     0.153
# 4                     0.158
# 5                     0.161
# 6                     0.176
# 7                     0.177
# 8                     0.185
# 9                     0.201
#
# [10 rows x 31 columns]

# %%
al = 'UNCERTAINTY' # choose UNCERTAINTY or RANDOM active learning strategy 
dataset = 'clef' # choose clef or episte 
language_model = 'BERT' # choose glove, w2vec, BERT, BioBERT
models = ['MLP', 'SVMrbf', 'LR', 'RF']
metric = 're@10' # choose r@10, r@20, r@30, p@10, p@20, p@30 , MAP, lastrel, WSS

COLUMNS = [al + dataset + language_model + m + metric for m in models ]


# standard deviation 
df_stdevs = pd.read_csv('results/{}_results_stdevs.csv'.format(dataset), sep=';' )

df[COLUMNS]
# Out:
#    UNCERTAINTYclefBERTMLPre@10  UNCERTAINTYclefBERTSVMrbfre@10  \
# 0                        0.256                           0.042
# 1                        0.294                           0.214
# 2                        0.328                           0.252
# 3                        0.350                           0.382
# 4                        0.353                           0.427
# 5                        0.372                           0.469
# 6                        0.394                           0.485
# 7                        0.419                           0.505
# 8                        0.419                           0.547
# 9                        0.481                           0.560
#
#    UNCERTAINTYclefBERTLRre@10  UNCERTAINTYclefBERTRFre@10
# 0                       0.224                       0.286
# 1                       0.350                       0.348
# 2                       0.357                       0.385
# 3                       0.379                       0.408
# 4                       0.421                       0.444
# 5                       0.493                       0.503
# 6                       0.521                       0.509
# 7                       0.537                       0.513
# 8                       0.543                       0.546
# 9                       0.561                       0.565

# %%
df_stdevs
# Out:
#    UNCERTAINTYclefw2vecMLPre@10  UNCERTAINTYclefw2vecRFre@10  \
# 0                         0.043                        0.042
# 1                         0.041                        0.045
# 2                         0.044                        0.048
# 3                         0.045                        0.046
# 4                         0.044                        0.048
# 5                         0.046                        0.048
# 6                         0.049                        0.049
# 7                         0.051                        0.053
# 8                         0.048                        0.054
# 9                         0.050                        0.052
#
#    UNCERTAINTYclefw2vecLRre@10  UNCERTAINTYclefw2vecSVMrbfre@10  \
# 0                        0.044                            0.036
# 1                        0.046                            0.045
# 2                        0.051                            0.049
# 3                        0.047                            0.052
# 4                        0.058                            0.052
# 5                        0.054                            0.051
# 6                        0.055                            0.052
# 7                        0.058                            0.052
# 8                        0.054                            0.052
# 9                        0.054                            0.055
#
#    UNCERTAINTYclefgloveMLPre@10  UNCERTAINTYclefgloveRFre@10  \
# 0                         0.039                        0.040
# 1                         0.051                        0.046
# 2                         0.051                        0.047
# 3                         0.050                        0.047
# 4                         0.050                        0.050
# 5                         0.051                        0.051
# 6                         0.050                        0.053
# 7                         0.051                        0.053
# 8                         0.051                        0.051
# 9                         0.051                        0.053
#
#    UNCERTAINTYclefgloveLRre@10  UNCERTAINTYclefgloveSVMrbfre@10  \
# 0                        0.040                            0.033
# 1                        0.045                            0.036
# 2                        0.046                            0.051
# 3                        0.047                            0.053
# 4                        0.048                            0.052
# 5                        0.053                            0.052
# 6                        0.052                            0.053
# 7                        0.052                            0.053
# 8                        0.053                            0.059
# 9                        0.051                            0.059
#
#    UNCERTAINTYclefBERTMLPre@10  UNCERTAINTYclefBERTRFre@10  \
# 0                        0.053                       0.048
# 1                        0.046                       0.048
# 2                        0.046                       0.049
# 3                        0.053                       0.050
# 4                        0.052                       0.050
# 5                        0.054                       0.051
# 6                        0.050                       0.052
# 7                        0.044                       0.051
# 8                        0.050                       0.052
# 9                        0.053                       0.052
#
#                ...               RANDOMclefgloveLRre@10  \
# 0              ...                                0.042
# 1              ...                                0.045
# 2              ...                                0.045
# 3              ...                                0.044
# 4              ...                                0.044
# 5              ...                                0.045
# 6              ...                                0.046
# 7              ...                                0.046
# 8              ...                                0.046
# 9              ...                                0.046
#
#    RANDOMclefgloveSVMrbfre@10  RANDOMclefBERTMLPre@10  RANDOMclefBERTRFre@10  \
# 0                       0.032                   0.050                  0.049
# 1                       0.037                   0.040                  0.049
# 2                       0.043                   0.037                  0.049
# 3                       0.045                   0.041                  0.050
# 4                       0.047                   0.044                  0.051
# 5                       0.047                   0.045                  0.050
# 6                       0.046                   0.037                  0.052
# 7                       0.047                   0.037                  0.053
# 8                       0.047                   0.038                  0.053
# 9                       0.048                   0.044                  0.054
#
#    RANDOMclefBERTLRre@10  RANDOMclefBERTSVMrbfre@10  \
# 0                  0.053                      0.035
# 1                  0.053                      0.038
# 2                  0.051                      0.050
# 3                  0.055                      0.051
# 4                  0.052                      0.050
# 5                  0.052                      0.052
# 6                  0.052                      0.054
# 7                  0.053                      0.054
# 8                  0.053                      0.055
# 9                  0.053                      0.054
#
#    RANDOMclefBioBERTMLPre@10  RANDOMclefBioBERTRFre@10  \
# 0                      0.054                     0.044
# 1                      0.054                     0.040
# 2                      0.050                     0.041
# 3                      0.048                     0.041
# 4                      0.044                     0.039
# 5                      0.051                     0.041
# 6                      0.046                     0.043
# 7                      0.045                     0.046
# 8                      0.046                     0.049
# 9                      0.047                     0.049
#
#    RANDOMclefBioBERTLRre@10  RANDOMclefBioBERTSVMrbfre@10
# 0                     0.053                         0.036
# 1                     0.054                         0.040
# 2                     0.054                         0.045
# 3                     0.054                         0.049
# 4                     0.054                         0.053
# 5                     0.054                         0.054
# 6                     0.055                         0.054
# 7                     0.055                         0.055
# 8                     0.055                         0.055
# 9                     0.058                         0.053
#
# [10 rows x 32 columns]

# %%
df_results = df[COLUMNS]
df_stdevs_results = df_stdevs[COLUMNS]

#change columns names 
df_results.columns = [[ language_model + m for m in models ]]

df_results['x'] = range(1,11)

df_results
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#   BERTMLP BERTSVMrbf BERTLR BERTRF   x
# 0   0.256      0.042  0.224  0.286   1
# 1   0.294      0.214  0.350  0.348   2
# 2   0.328      0.252  0.357  0.385   3
# 3   0.350      0.382  0.379  0.408   4
# 4   0.353      0.427  0.421  0.444   5
# 5   0.372      0.469  0.493  0.503   6
# 6   0.394      0.485  0.521  0.509   7
# 7   0.419      0.505  0.537  0.513   8
# 8   0.419      0.547  0.543  0.546   9
# 9   0.481      0.560  0.561  0.565  10

# %%
plt.errorbar(
    [i for i in range(10)],  # X
    [x[0] for x in df_results['{}{}'.format(language_model, models[0])].values.tolist()], # Y
    yerr=sum(df_stdevs_results[al + dataset + language_model + models[0] + metric])/10,     # Y-average-errors
    fmt="o", # format line like for plot()
    linewidth=1,# width of plot line
    markersize=8,
    color = 'blue',
    capsize=5,
    ecolor='blue',
    label='{}{}'.format(language_model,models[0]),
    linestyle='dashed'
    )

plt.errorbar(
    [i for i in range(10)],  # X
    [x[0] for x in df_results['{}{}'.format(language_model, models[1])].values.tolist()], # Y
    yerr=sum(df_stdevs_results[al + dataset + language_model + models[1] + metric])/10,     # Y-errors
    fmt="o", # format line like for plot()
    linewidth=1,# width of plot line
    markersize=8,
    color = 'green',
    capsize=5,
    ecolor='green',
    label='{}{}'.format(language_model,models[1]),
    linestyle='dashed'
)


plt.errorbar(
    [i for i in range(10)],  # X
    [x[0] for x in df_results['{}{}'.format(language_model, models[2])].values.tolist()], # Y
    yerr=sum(df_stdevs_results[al + dataset + language_model + models[2] + metric])/10,     # Y-errors
    fmt="o", # format line like for plot()
    linewidth=1,# width of plot line
    markersize=8,
    color = 'orange',
    capsize=5,
    ecolor='orange',
    label='{}{}'.format(language_model,models[2]),
    linestyle='dashed'
)

plt.errorbar(
    [i for i in range(10)],  # X
    [x[0] for x in df_results['{}{}'.format(language_model, models[3])].values.tolist()], # Y
    yerr=sum(df_stdevs_results[al + dataset + language_model + models[3] + metric])/10,     # Y-errors
    fmt="o", # format line like for plot()
    linewidth=1,# width of plot line
    markersize=8,
    color = 'red',
    capsize=5,
    ecolor='red',
    label='{}{}'.format(language_model,models[3]),
    linestyle='dashed'
)


ylim(0,0.7)


plt.ylabel("recall@10")
plt.xlabel("iterations")
plt.legend(loc='upper right')
plt.title(' {} document representation {} Sampling'.format(language_model.capitalize(), al.capitalize()) )


# save plot
plt.savefig('{}_{}_{}.eps'.format(dataset, language_model, al ), format='eps')
